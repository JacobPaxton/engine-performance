# %% [markdown]
# # Overview
# This notebook contains my work for acquisition and preparation of the scraped dyno run data.
#
# # Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import re

import wrangle

# %% [markdown]
# # Car Info CSV work
# Let's look at car_info.csv first.

# %%
# ingest car info csv
info = pd.read_csv('car_info.csv')
info
# Out:
#        Run                 Date                      Car             Name  \
# 0        4  11-08-2009 05:51 pm         2009 Nissan GT-R      GOTO:Racing
# 1        5  10-21-2009 01:08 pm  2002 Subaru Impreza WRX     Neil Bywater
# 2       31  11-12-2009 10:56 am         2010 Nissan GT-R  Jason McCartney
# 3       32  11-12-2009 10:57 am         2010 Nissan GT-R       Mike Cheng
# 4       33  11-02-2009 10:58 am         2009 Nissan GT-R   Dave Pickering
# ...    ...                  ...                      ...              ...
# 4950  5926  10-13-2017 12:25 pm   2016 Volkswagen Golf R      COBB Tuning
# 4951  5927  10-13-2017 12:25 pm   2016 Volkswagen Golf R      COBB Tuning
# 4952  5933  10-13-2017 12:47 pm   2016 Volkswagen Golf R      COBB Tuning
# 4953  5934  10-13-2017 12:47 pm   2016 Volkswagen Golf R      COBB Tuning
# 4954  5936  10-13-2017 12:48 pm   2016 Volkswagen Golf R      COBB Tuning
#
#                                                   Specs
# 0     Stock engine internals, AMS turbo upgrade, Dea...
# 1     2.5L Sti longblock (No avcs)FP Green, APS 525 ...
# 2     2010 GTR - Completely stock - 100 octane fuel ...
# 3     2010 GTR - stock with high flow downpipe - 94 ...
# 4     2009 GTR - stage 2 with full exhaust and stock...
# ...                                                 ...
# 4950                                            Stage 1
# 4951                                            Stage 2
# 4952                                              Stock
# 4953                                 Stage 1 High Boost
# 4954                                            Stage 3
#
# [4955 rows x 5 columns]

# %%
# check nulls
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Run     4955 non-null   int64
#  1   Date    4955 non-null   object
#  2   Car     4955 non-null   object
#  3   Name    4955 non-null   object
#  4   Specs   4955 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 193.7+ KB

# %% [markdown]
# **Looks good, we will need to do a few things before Explore:**
# - Split the Car column into year, make, and model columns
# - Convert the Date column to a datetime format
# - Split the runs into Train, Validate, and Test
#
# ## 'Car' column split into year, make, and model columns

# %%
# checking how we could split the Car column
print(info.Car.unique()[:10].tolist())
# Out:
# ['2009 Nissan GT-R', '2002 Subaru Impreza WRX', '2010 Nissan GT-R', '2004 Subaru Impreza WRX STI', '2010 Mazda Mazdaspeed3', '2006 Subaru Impreza WRX STI', '2009 Honda Civic Si', '2007 Mazda Mazdaspeed3', '2005 Subaru Outback XT', '1998 Subaru Impreza RS']

# %%
# using first-4 characters as year
info['car_year'] = info.Car.str[:4]
info.car_year.sample(3, random_state=1)
# Out:
# 1271    2010
# 2360    2008
# 2369    2011
# Name: car_year, dtype: object

# %%
# splitting the rest of the string into make and model
make_model = info.Car.str.extract(r'\W(.*?)\W(.*?)$')
# using the second word as the make
info['car_make'] = make_model[0]
# using the last portion as the model
info['car_model'] = make_model[1]

# check work
info.head(3)
# Out:
#    Run                 Date                      Car             Name  \
# 0    4  11-08-2009 05:51 pm         2009 Nissan GT-R      GOTO:Racing
# 1    5  10-21-2009 01:08 pm  2002 Subaru Impreza WRX     Neil Bywater
# 2   31  11-12-2009 10:56 am         2010 Nissan GT-R  Jason McCartney
#
#                                                Specs car_year car_make  \
# 0  Stock engine internals, AMS turbo upgrade, Dea...     2009   Nissan
# 1  2.5L Sti longblock (No avcs)FP Green, APS 525 ...     2002   Subaru
# 2  2010 GTR - Completely stock - 100 octane fuel ...     2010   Nissan
#
#      car_model
# 0         GT-R
# 1  Impreza WRX
# 2         GT-R

# %%
# drop redundant Car column
info = info.drop(columns='Car')
info.head(3)
# Out:
#    Run                 Date             Name  \
# 0    4  11-08-2009 05:51 pm      GOTO:Racing
# 1    5  10-21-2009 01:08 pm     Neil Bywater
# 2   31  11-12-2009 10:56 am  Jason McCartney
#
#                                                Specs car_year car_make  \
# 0  Stock engine internals, AMS turbo upgrade, Dea...     2009   Nissan
# 1  2.5L Sti longblock (No avcs)FP Green, APS 525 ...     2002   Subaru
# 2  2010 GTR - Completely stock - 100 octane fuel ...     2010   Nissan
#
#      car_model
# 0         GT-R
# 1  Impreza WRX
# 2         GT-R

# %% [markdown]
# ## Datetime column

# %%
# capture date and time into columns
date_time = info.Date.str.extract(r'^(.*?) (.*?)$')

# %%
# show discrepancy in date
date_time[0].unique().tolist()[53:58]
# Out:
# ['10-27-2009', '11-05-2009', '10-26-2009', '11-30--0001', '12-01-2009']

# %% [markdown]
# Runs are chronological from what I can tell, I bet we can fix the discrepancy with the correct year...

# %%
# check runs where with the incorrect year
info[info.Date.str.contains('11-30--0001')]
# Out:
#        Run                  Date            Name  \
# 98     160  11-30--0001 04:00 pm     Joey Hauser
# 117    180  11-30--0001 04:00 pm  Jeff Sponaugle
# 118    181  11-30--0001 04:00 pm  Jeff Sponaugle
# 119    182  11-30--0001 04:00 pm  Jeff Sponaugle
# 120    183  11-30--0001 04:00 pm      Tim Bailey
# 216    299  11-30--0001 04:00 pm    Sage Merrill
# 217    300  11-30--0001 04:00 pm    Sage Merrill
# 1338  1625  11-30--0001 03:35 pm    Mark Dickins
# 1339  1626  11-30--0001 04:34 pm    Mark Dickins
# 1404  1695  11-30--0001 04:41 pm         RUF RUF
# 1406  1697  11-30--0001 06:12 pm       David Liu
# 2139  2503  11-30--0001 05:21 pm     Mike McCall
# 2467  2883  11-30--0001 12:33 pm    Scott Bowman
# 2468  2884  11-30--0001 11:04 am    Scott Bowman
# 2949  3403  11-30--0001 03:42 pm    Scott Bowman
# 2950  3404  11-30--0001 11:59 am    Scott Bowman
# 2951  3405  11-30--0001 04:14 pm    Scott Bowman
# 2952  3406  11-30--0001 11:02 am    Scott Bowman
# 2953  3407  11-30--0001 05:11 pm    Scott Bowman
# 2954  3408  11-30--0001 03:11 pm    Scott Bowman
# 2955  3409  11-30--0001 03:56 pm    Scott Bowman
# 3522  4133  11-30--0001 07:47 pm    Anonymous 11
# 3523  4134  11-30--0001 07:47 pm    Anonymous 11
# 3524  4135  11-30--0001 07:47 pm    Anonymous 11
# 3525  4136  11-30--0001 07:47 pm    Anonymous 11
# 3652  4299  11-30--0001 11:30 am     COBB Tuning
# 3653  4300  11-30--0001 11:30 am     COBB Tuning
# 3654  4301  11-30--0001 02:22 pm     COBB Tuning
# 3655  4302  11-30--0001 02:22 pm     COBB Tuning
#
#                                                   Specs car_year    car_make  \
# 98                                            98 Octane     2008  Mitsubishi
# 117        Built 2.5L, GT30R .63 Rotated Kit, 92 Octane     2008      Subaru
# 118               Built H6, Custom GT35R Kit, 92 Octane     2002      Subaru
# 119              Built H6, Custom GT35R Kit, 100 Octane     2002      Subaru
# 120   Built 2.5L, Cosworth Heads & Cams, GT35R, AEM ...     2004      Subaru
# 216   Evo3 16g, TMIC, 750cc Injectors, SF Intake, 18...     2002      Subaru
# 217   Evo3 16g, TMIC, 750cc Injectors, SF Intake, 16...     2002      Subaru
# 1338                            Stage 2 19psi 91 Octane     2007      Subaru
# 1339                                  Stage 2 21psi E85     2007      Subaru
# 1404                                     Stock Baseline     2007     Porsche
# 1406                                          Stock Run     1996       Mazda
# 2139  AP Stg 2 93 v300 - 2; AA Downpipes, Berk Catba...     2008         BMW
# 2467                         1M Final Aggressive Stage1     2011         BMW
# 2468                                     1M stock cntrl     2011         BMW
# 2949                                  stock flash cntrl     2011         BMW
# 2950                                  stage 1 aggr v401     2011         BMW
# 2951                                  stage1 Sport v401     2011         BMW
# 2952                             stage1+FMIC Sport v401     2011         BMW
# 2953                             Stage1+FMIC Aggr Final     2011         BMW
# 2954                             stage2+FMIC sport v401     2011         BMW
# 2955                              stage2+FMIC AGGR v401     2011         BMW
# 3522                    Stage1 Aggressive Alpha 135 DCT     2012         BMW
# 3523                                        Stock Flash     2012         BMW
# 3524                    Stage1 Aggressive Alpha 135 DCT     2012         BMW
# 3525                                        Stock Flash     2012         BMW
# 3652                             Stage0 Stock Cat Cntrl     2011         BMW
# 3653                              Stage0 COBB Cat Cntrl     2011         BMW
# 3654                          stage2 agg Cntrl Stock DP     2011         BMW
# 3655                           stage2 agg Cntrl COBB DP     2011         BMW
#
#             car_model
# 98              EVO X
# 117   Impreza WRX STI
# 118       Impreza WRX
# 119       Impreza WRX
# 120   Impreza WRX STI
# 216       Impreza WRX
# 217       Impreza WRX
# 1338  Impreza WRX STI
# 1339  Impreza WRX STI
# 1404              911
# 1406       MX-5/Miata
# 2139             135i
# 2467               1M
# 2468               1M
# 2949               1M
# 2950               1M
# 2951               1M
# 2952               1M
# 2953               1M
# 2954               1M
# 2955               1M
# 3522             135i
# 3523             135i
# 3524             135i
# 3525             135i
# 3652             335i
# 3653             335i
# 3654             335i
# 3655             335i

# %%
def run_date_fixer(col):
    """ Pass back the previous and next run numbers for erroneous run date runs, if available """
    col_prev = col - 1
    col_next = col + 1
    new_col = col.append(col_prev).append(col_next).tolist()
    return new_col

# %%
# get list of runs
run_checks = run_date_fixer(info[info.Date.str.contains('11-30--0001')].Run)

# check work
run_checks.sort()
print(run_checks)
# Out:
# [159, 160, 161, 179, 180, 180, 181, 181, 181, 182, 182, 182, 183, 183, 184, 298, 299, 299, 300, 300, 301, 1624, 1625, 1625, 1626, 1626, 1627, 1694, 1695, 1696, 1696, 1697, 1698, 2502, 2503, 2504, 2882, 2883, 2883, 2884, 2884, 2885, 3402, 3403, 3403, 3404, 3404, 3404, 3405, 3405, 3405, 3406, 3406, 3406, 3407, 3407, 3407, 3408, 3408, 3408, 3409, 3409, 3410, 4132, 4133, 4133, 4134, 4134, 4134, 4135, 4135, 4135, 4136, 4136, 4137, 4298, 4299, 4299, 4300, 4300, 4300, 4301, 4301, 4301, 4302, 4302, 4303]

# %%
# use run_checks list to pass back rows with that run number
info[info.Run.isin(run_checks[:20])]
# Out:
#      Run                  Date            Name  \
# 97   159   10-26-2009 11:38 am   Jake Zvirzdys
# 98   160  11-30--0001 04:00 pm     Joey Hauser
# 99   161   12-07-2009 11:42 am       John Wulf
# 116  179   10-08-2009 03:38 pm      Tad Ogland
# 117  180  11-30--0001 04:00 pm  Jeff Sponaugle
# 118  181  11-30--0001 04:00 pm  Jeff Sponaugle
# 119  182  11-30--0001 04:00 pm  Jeff Sponaugle
# 120  183  11-30--0001 04:00 pm      Tim Bailey
# 121  184   11-30-2009 03:46 pm       Tim Diens
# 215  298   01-01-2010 05:08 pm     Lance Lucas
# 216  299  11-30--0001 04:00 pm    Sage Merrill
# 217  300  11-30--0001 04:00 pm    Sage Merrill
#
#                                                  Specs car_year    car_make  \
# 97                                  Stage 2, 92 Octane     2006      Subaru
# 98                                           98 Octane     2008  Mitsubishi
# 99   Stage 2, AEM Intake, AVO TMIC, 17.5psi, 92 Octane     2006      Subaru
# 116                                 Stage 2, 92 Octane     2008  Mitsubishi
# 117       Built 2.5L, GT30R .63 Rotated Kit, 92 Octane     2008      Subaru
# 118              Built H6, Custom GT35R Kit, 92 Octane     2002      Subaru
# 119             Built H6, Custom GT35R Kit, 100 Octane     2002      Subaru
# 120  Built 2.5L, Cosworth Heads & Cams, GT35R, AEM ...     2004      Subaru
# 121                                   Stock, 92 Octane     2009      Subaru
# 215  GT35R .82, Built 2.5L Longblock, 272 Cams, 21-...     2004      Subaru
# 216  Evo3 16g, TMIC, 750cc Injectors, SF Intake, 18...     2002      Subaru
# 217  Evo3 16g, TMIC, 750cc Injectors, SF Intake, 16...     2002      Subaru
#
#            car_model
# 97       Impreza WRX
# 98             EVO X
# 99      Legacy 2.5GT
# 116        EVO X GSR
# 117  Impreza WRX STI
# 118      Impreza WRX
# 119      Impreza WRX
# 120  Impreza WRX STI
# 121  Impreza WRX STI
# 215      Impreza WRX
# 216      Impreza WRX
# 217      Impreza WRX

# %% [markdown]
# Based on the need to clean 'Date' column and the lack of value it provides, I'll just drop the 'Date' column.

# %%
# drop Date column
info = info.drop(columns='Date')
info.head(3)
# Out:
#    Run             Name                                              Specs  \
# 0    4      GOTO:Racing  Stock engine internals, AMS turbo upgrade, Dea...
# 1    5     Neil Bywater  2.5L Sti longblock (No avcs)FP Green, APS 525 ...
# 2   31  Jason McCartney  2010 GTR - Completely stock - 100 octane fuel ...
#
#   car_year car_make    car_model
# 0     2009   Nissan         GT-R
# 1     2002   Subaru  Impreza WRX
# 2     2010   Nissan         GT-R

# %% [markdown]
# Looks good- we'll split our data after we look into dyno_runs.csv next.
#
# # Dyno Runs CSV work
# Now let's look at dyno_runs.csv.

# %%
# ingest run data
runs = pd.read_csv('dyno_runs.csv', index_col=0)
runs
# Out:
#           Run     RPM      HP  Torque   AFR  Boost
# 0           4  2200.0  106.10  252.50  7.47   4.12
# 1           4  2300.0  145.80  333.10  7.48   5.43
# 2           4  2400.0  177.90  389.50  7.48   6.78
# 3           4  2500.0  202.30  424.90  7.48   8.15
# 4           4  2600.0  221.80  447.90  7.48   9.55
# ...       ...     ...     ...     ...   ...    ...
# 2044935  5951     3.0  151.91  316.87   NaN    NaN
# 2044936  5951     4.0  253.33  380.61   NaN    NaN
# 2044937  5951     5.0  300.56  349.22   NaN    NaN
# 2044938  5951     6.0  305.76  292.02   NaN    NaN
# 2044939  5951     7.0  291.41  234.79   NaN    NaN
#
# [2044940 rows x 6 columns]

# %%
# check nulls
runs.isna().sum()
# Out:
# Run            0
# RPM         7214
# HP             0
# Torque         0
# AFR       199729
# Boost     197572
# dtype: int64

# %%
# figure out which runs have nulls in RPM column
null_RPM_runs = runs[runs.RPM.isna()].Run.unique().tolist()
print(null_RPM_runs)
# Out:
# [978, 979, 1578, 3266, 3454, 3498, 3631, 3632, 3682, 4022, 4023, 4330, 4331, 4652, 4670, 4671, 4672, 5025, 5380, 5403, 5407, 5434]

# %%
# check if all RPM values are null in these runs, or just partially null
runs[runs.Run.isin(null_RPM_runs)].RPM.isna().sum()
# Out:
# 7214

# %% [markdown]
# All RPM values are null in these runs. Let's see if there's a clue in car_info.csv as to why.

# %%
# check car info for runs with nulls in RPM
info[info.Run.isin(null_RPM_runs)]
# Out:
#        Run          Name                                   Specs car_year  \
# 3102  3682  David Palmer  91 oct, COBB downpipe, COBB AP+PRoTUne     2010
#
#      car_make car_model
# 3102   Subaru  Forester

# %% [markdown]
# Okay, it seems these runs don't exist in car_info.csv. Only one run does. We will therefore drop all rows with nulls in the RPM column.

# %%
# drop nulls
runs = runs[runs.RPM.notna()].reset_index(drop=True)

# %% [markdown]
# Now let's see if dropping the runs with nulls in AFR or Boost is fine.

# %%
# check percentage of rows with nulls in either AFR or Boost columns
print(str(int((runs.AFR.isna() | runs.Boost.isna()).sum() / runs.shape[0] * 100)) + '%')
# Out:
# 15%

# %%
# is the Boost column less than 15%?
print(str(int(runs.Boost.isna().sum() / runs.shape[0] * 100)) + '%')
# Out:
# 9%

# %% [markdown]
# So, I'm going to drop the 'AFR' column and drop rows with nulls in the 'Boost' column. Let me explain why.
#
# **Why I'm dropping the 'AFR' column:**
# 1. A balance in air-fuel ratio (AFR) provides the most horsepower, and this ratio is manually adjusted
# 2. This balance point is different for different cars and setups
# 3. The car variety in this dataset is too diverse to consider raw values in AFR
# 4. Analysis of AFR on a car-by-car basis is possible, but not valuable to a general audience owning various vehicles
#
# **Why I'm only dropping nulls in the Boost column:**
# 1. In nearly all cases, as boost increases, power increases
# 2. The few potential exceptions to this relationship will likely be explained by the parts in the 'Specs' column
# 3. Raw increases in 'Boost' values will show increases in horsepower, so it's valuable to keep this as a feature

# %%
# dropping AFR column
runs = runs.drop(columns = 'AFR')

# dropping rows with nulls in Boost column
runs = runs[runs.Boost.notna()]

# check work
runs.isna().sum()
# Out:
# Run       0
# RPM       0
# HP        0
# Torque    0
# Boost     0
# dtype: int64

# %% [markdown]
# Looks good, I'll push these changes to wrangle.py now.
#
# Checking if the changes worked...

# %%
# acquire, clean, and split data using script
info_train, runs_train = wrangle.prep_explore_MVP()

# %%
# check if run numbers in train split are the same
info_train.run.sort_values().unique().tolist() == runs_train.run.sort_values().unique().tolist()
# Out:
# True

# %% [markdown]
# # Exploration Re-Wrangle
# In Explore I noticed more prep that needs to be done with the data, below captures that work.

# %%
pd.set_option('display.max_colwidth', None)
info = info.reset_index(drop=True)
info
# Out:
#        Run             Name  \
# 0        4      GOTO:Racing
# 1        5     Neil Bywater
# 2       31  Jason McCartney
# 3       32       Mike Cheng
# 4       33   Dave Pickering
# ...    ...              ...
# 4950  5926      COBB Tuning
# 4951  5927      COBB Tuning
# 4952  5933      COBB Tuning
# 4953  5934      COBB Tuning
# 4954  5936      COBB Tuning
#
#                                                                                                                                                                                             Specs  \
# 0     Stock engine internals, AMS turbo upgrade, Deatschwerks 800cc injectors, full catless 3" open exhaust, Harman Motive custom 3.1" ID intake with stock MAF sensors, 100 octane unleaded fuel
# 1                                                                          2.5L Sti longblock (No avcs)FP Green, APS 525 FMIC, APS 65mm intake Cobb turbo-back, APS turbo inlet, DW 850 injectors
# 2                                                                                                               2010 GTR - Completely stock - 100 octane fuel - Cobb stage 1 v110 100 octane beta
# 3                                                                                                              2010 GTR - stock with high flow downpipe - 94 octane - COBB v110 beta stage 2 tune
# 4                                                                                                     2009 GTR - stage 2 with full exhaust and stock downpipes - cobb v110 stage 2 92 octane beta
# ...                                                                                                                                                                                           ...
# 4950                                                                                                                                                                                      Stage 1
# 4951                                                                                                                                                                                      Stage 2
# 4952                                                                                                                                                                                        Stock
# 4953                                                                                                                                                                           Stage 1 High Boost
# 4954                                                                                                                                                                                      Stage 3
#
#      car_year    car_make    car_model
# 0        2009      Nissan         GT-R
# 1        2002      Subaru  Impreza WRX
# 2        2010      Nissan         GT-R
# 3        2010      Nissan         GT-R
# 4        2009      Nissan         GT-R
# ...       ...         ...          ...
# 4950     2016  Volkswagen       Golf R
# 4951     2016  Volkswagen       Golf R
# 4952     2016  Volkswagen       Golf R
# 4953     2016  Volkswagen       Golf R
# 4954     2016  Volkswagen       Golf R
#
# [4955 rows x 6 columns]

# %%
def check_non_keywords(df, col):
    """ Check value counts of words I did not designate as keywords in product names """
    # check all rows without keywords for each unique word's value counts in entire list
    print(
        pd.Series( # make a Series of each instance of each word
            ' '.join(
                    df[~df.has_keyword]    # look at rows we haven't caught with a keyword yet
                    [col].tolist()        # put all 'name' cells in a list
                    ).split()        # join all lists into one string, then split the string into a list of each word
        ).value_counts()        # calculate the value counts of each word in the series
        .head(20)         # display the top 10 (changed from 30 to 10 after the words I wanted were captured)
    )

# %%
info['has_keyword'] = False

# %%
check_non_keywords(info, 'Specs')
# Out:
# COBB           3437
# Tuning         2859
# Octane         2384
# 92             1627
# AccessPORT,    1241
# Perrin         1044
# 93             1002
# Stage           899
# -               880
# Intake,         832
# SF              698
# Fuel            625
# Injectors,      597
# 2               583
# FMIC,           491
# 3               464
# Catless         460
# Turboback,      458
# Downpipe,       446
# E85             421
# dtype: int64

# %% [markdown]
# ## PSI

# %%
# capture nearly all psi ratings
info['psi'] = info.Specs.str.extract(r'^.*\s(\d+\.*\d*)\s?[Pp][Ss][Ii].*$')

# %%
# fix '(number) Peak PSI' issue
newthing = info.Specs.str.extract(r'^.*\b(\d\d\.\d) Peak PSI.*$')
indices = newthing[newthing[0].notna()].index
for ind in indices:
    info.loc[ind, 'psi'] = newthing[0][ind]

# %%
# check if 'Peak PSI' has a number in the 'psi' column now
info[info.Specs.str.contains('Peak PSI')]
# Out:
#      Run         Name                                          Specs car_year  \
# 731  928  COBB Tuning  Stage 2 OTS Mapping- 17.5 Peak PSI- 93 Octane     2010
# 732  929  COBB Tuning  Stage 2 OTS Mapping- 14.5 Peak PSI- 91 Octane     2010
#
#     car_make     car_model  has_keyword   psi
# 731   Subaru  Legacy 2.5GT        False  17.5
# 732   Subaru  Legacy 2.5GT        False  14.5

# %%
# indicate in new column if Specs has 'psi' in it
info['has_psi'] = info.Specs.str.contains('PSI|psi')

# %%
# check all occurences where 'psi' is null but Specs does have a 'psi'
info[(info.has_psi) & (info.psi.isna())][['Specs','psi','has_psi']]
# Out:
#                                                                                                                                                 Specs  \
# 215                                                                                    GT35R .82, Built 2.5L Longblock, 272 Cams, 21-19psi Boost, E85
# 241                                                                                                                                       18psi w/E85
# 242                                                                                                                                      8.5psi w/E85
# 243                                                                                                                                       16psi w/E85
# 330                 27 psi 93 octane -FP Red with Forge WG Act., DW 800, AMS Downpipe, AMS Intercooler and Pipes, Agency Power Intake, Prodrive 3Port
# ...                                                                                                                                               ...
# 4860  15psi - E70 - COBB Accessport w/ COBB Flex Fuel Kit, COBB Turboback, COBB EWG- Rerouted, Process West TMIC, ID 1000cc Injectors, AEM Fuel Pump.
# 4861  17psi - E70 - COBB Accessport w/ COBB Flex Fuel Kit, COBB Turboback, COBB EWG- Rerouted, Process West TMIC, ID 1000cc Injectors, AEM Fuel Pump.
# 4862  19psi - E70 - COBB Accessport w/ COBB Flex Fuel Kit, COBB Turboback, COBB EWG- Rerouted, Process West TMIC, ID 1000cc Injectors, AEM Fuel Pump.
# 4875               18psi - COBB SF Intake/Airbox, Perrin TMIC, FIC 1100cc Injectors, Fuel Pump, AMR Big Tube Header, Turbosmart EWG, and Invidia TBE.
# 4876               19psi - COBB SF Intake/Airbox, Perrin TMIC, FIC 1100cc Injectors, Fuel Pump, AMR Big Tube Header, Turbosmart EWG, and Invidia TBE.
#
#       psi  has_psi
# 215   NaN     True
# 241   NaN     True
# 242   NaN     True
# 243   NaN     True
# 330   NaN     True
# ...   ...      ...
# 4860  NaN     True
# 4861  NaN     True
# 4862  NaN     True
# 4875  NaN     True
# 4876  NaN     True
#
# [243 rows x 3 columns]

# %% [markdown]
# Looks good for PSI, let's do fuel octane now.
#
# ## Octane

# %%
info['octane'] = info.Specs.str.extract(r'^.*\b(\d+)[,\s]?\s?[Oo][Cc][Tt].*$')
info['has_octane'] = info.Specs.str.contains('Octane|octane')
info[(info.has_octane) & (info.octane.isna())][['Specs','octane','has_octane']]
# Out:
#                                                                                              Specs  \
# 580                                                               FP Green 20psi E85 Octane Sport#
# 2412  COBB Socal Tuned "Sport" map, HKS DP, Midpipe and CBE. GotBoost 3" intakes. 91 CA Octane :-(
# 2413   COBB Socal Tuned "Mild" map, HKS DP, Midpipe and CBE. GotBoost 3" intakes. 91 CA Octane :-(
# 2414                          SP Eng map, HKS DP, Midpipe and CBE, Panel filters. 91 CA Octane :-(
# 4460                                       ANC91 Octane - Added Blouch Dom1.5XTR Turbo, COBB 1300s
# 4905                                                               ByDesign StageIV - ACN91 Octane
#
#      octane  has_octane
# 580     NaN        True
# 2412    NaN        True
# 2413    NaN        True
# 2414    NaN        True
# 4460    NaN        True
# 4905    NaN        True

# %%
# octane overall capture
info['octane'] = info.Specs.str.extract(r'^.*\b(\d+)[,\s]?\s?[Oo][Cc][Tt].*$')
# 93 octane fuel
octane_93_indices = info[info.Specs.str.contains(' 93 ')].index
for ind in octane_93_indices:
    info.loc[ind, 'octane'] = 93
# 91 octane fuel
octane_91_indices = info[info.Specs.str.contains('ACN91|ANC91|91 CA| 91 ')].index
for ind in octane_91_indices:
    info.loc[ind, 'octane'] = 91
# 104 octane fuel
octane_104_indices = info[info.Specs.str.contains('104')].index
for ind in octane_104_indices:
    info.loc[ind, 'octane'] = 104
# e85 fuel
e85_indices = info[info.Specs.str.contains('E85|E-85')].index
for ind in e85_indices:
    info.loc[ind, 'octane'] = 105
# MS109 fuel
ms109_indices = info[info.Specs.str.contains('MS109')].index
for ind in ms109_indices:
    info.loc[ind, 'octane'] = 109

# %%
info[(info.has_octane) & (info.octane.isna())][['Specs','octane','has_octane']]
# Out:
# Empty DataFrame
# Columns: [Specs, octane, has_octane]
# Index: []

# %% [markdown]
# Looks good for Octane, let's move on to the AccessPORT, which is a modification to the ECU. In layman's terms it adjusts the car's computer so that the car performs better.

# %%
# drop unnecessary columns
info = info.drop(columns=['has_psi','has_octane'])

# %% [markdown]
# # Post-MVP
# ## Add Stock Horsepower Information for 'car_model' Values

# %%
# create merge-ready dataframe of stock horsepower values
hp_dict = wrangle.horsepower_dict()
stock_hp_df = pd.DataFrame(hp_dict, index=['stock_hp']).T.reset_index().rename(columns={'index':'car_model'})

# %%
# add stock_hp column to car_info dataframe
info['car_model'] = info['car_year'].astype('str') + ' ' + info['car_model']
info = pd.merge(left=info, right=stock_hp_df, on='car_model')

# %%
info.head(3)
# Out:
#    Run            Name  \
# 0    4     GOTO:Racing
# 1   33  Dave Pickering
# 2   54      Tim Bailey
#
#                                                                                                                                                                                          Specs  \
# 0  Stock engine internals, AMS turbo upgrade, Deatschwerks 800cc injectors, full catless 3" open exhaust, Harman Motive custom 3.1" ID intake with stock MAF sensors, 100 octane unleaded fuel
# 1                                                                                                  2009 GTR - stage 2 with full exhaust and stock downpipes - cobb v110 stage 2 92 octane beta
# 2                                                                                                                                                                   2009 GTR stage 2 91 octane
#
#   car_year car_make  car_model  has_keyword  psi octane  stock_hp
# 0     2009   Nissan  2009 GT-R        False  NaN    100       480
# 1     2009   Nissan  2009 GT-R        False  NaN     92       480
# 2     2009   Nissan  2009 GT-R        False  NaN     91       480

# %% [markdown]
# ## Imputing PSI Using Max 'boost' Value From Run

# %%
# group runs by max boost value
max_boost_df = pd.DataFrame(runs.groupby('Run').Boost.max()).reset_index()
# merge with car_info
info = pd.merge(left=info, right=max_boost_df, on='Run')
# check if psi and Boost are similar for non-null psi values
info[['psi','Boost']].sample(10, random_state=1)
# Out:
#        psi  Boost
# 453     20  20.70
# 364   17.5  17.00
# 372     18  18.28
# 1637    13  13.10
# 857     16  15.70
# 2204    18  18.10
# 2318   NaN  21.10
# 3054   NaN  28.40
# 3774    18  17.80
# 1647  16.5  16.92

# %% [markdown]
# Looks like we're safe to impute based on the run's max boost PSI value.

# %%
# fill nulls with max boost PSI value for run
info['psi'] = info['psi'].fillna((info.Boost * 2).astype('int') / 2) # keep .5 precision
# drop redundant 'Boost' column
info = info.drop(columns='Boost')

# %%
# check work
info.head()
# Out:
#    Run            Name  \
# 0    4     GOTO:Racing
# 1   33  Dave Pickering
# 2   54      Tim Bailey
# 3   55      Tim Bailey
# 4   66  Samuel Frankel
#
#                                                                                                                                                                                          Specs  \
# 0  Stock engine internals, AMS turbo upgrade, Deatschwerks 800cc injectors, full catless 3" open exhaust, Harman Motive custom 3.1" ID intake with stock MAF sensors, 100 octane unleaded fuel
# 1                                                                                                  2009 GTR - stage 2 with full exhaust and stock downpipes - cobb v110 stage 2 92 octane beta
# 2                                                                                                                                                                   2009 GTR stage 2 91 octane
# 3                                                                                                                                                                   2009 GTR stage 2 93 octane
# 4                                                                                                                                                                 Cat Back Ext. Stage 2 19 psi
#
#   car_year car_make  car_model  has_keyword   psi octane  stock_hp
# 0     2009   Nissan  2009 GT-R        False  22.0    100       480
# 1     2009   Nissan  2009 GT-R        False  17.5     92       480
# 2     2009   Nissan  2009 GT-R        False  17.0     91       480
# 3     2009   Nissan  2009 GT-R        False  17.0     93       480
# 4     2009   Nissan  2009 GT-R        False    19    NaN       480

# %% [markdown]
# ## Imputing Nulls in 'octane' Using Most Common Octane

# %%
# get most common fuel octane
info.octane.value_counts().head(3)
# Out:
# 92     1596
# 93      854
# 105     467
# Name: octane, dtype: int64

# %%
# fill octane nulls with 92
info['octane'] = info['octane'].fillna(92).astype('int')
# check work
info.sample(5, random_state=1)
# Out:
#        Run              Name  \
# 453   2148       Peter Cowan
# 364   4370  Reilley Friessen
# 372   5128      Joshua Munoz
# 1637  1892       Russ Hoefer
# 857    811       Brett Ensor
#
#                                                                                                                                                        Specs  \
# 453   COBB Tuning AccessPORT, GT2860 .63 A/R, Deatschwerks 850cc Injectors, Perrin Exhaust Manifold, Perrin Big MAF Intake, Catted Midpipe- 20psi- Pump Fuel
# 364                        COBB Tuning Accessport, Downpipes, Midpipe, HKS Catback, GotBoost 3" Intakes, SIR 750cc Injectors, '12 Inlets- 17.5psi- 92 Octane
# 372                                                                                                                                  Stage 3 18psi 93 Octane
# 1637                                                                        COBB Tuning AccessPORT, COBB Tuning SF Intake, Catted Downpipe- 13psi- 92 Octane
# 857                                                                    COBB Tuning AccessPORT, Perrin Catted Turboback Exhaust, AEM Intake- 16psi- 92 Octane
#
#      car_year car_make             car_model  has_keyword   psi  octane  \
# 453      2004   Subaru  2004 Impreza WRX STI        False    20      92
# 364      2010   Nissan             2010 GT-R        False  17.5      92
# 372      2010   Nissan             2010 GT-R        False    18      93
# 1637     2006   Subaru      2006 Impreza WRX        False    13      92
# 857      2008   Subaru  2008 Impreza WRX STI        False    16      92
#
#       stock_hp
# 453        300
# 364        485
# 372        485
# 1637       230
# 857        305

# %% [markdown]
# ## AccessPORT, OTS, ProTune, and Stages
# **The AccessPORT is a product that COBB Tuning offers to modify the engine control computer.** The modifications are advertised as increasing performance for a variety of cars using Off-The-Shelf (OTS) configurations. Anytime 'Access', 'OTS', or 'ProTune' is mentioned, the car's computer has been modified. Because this is an offer from COBB Tuning, we can expect it will generally be noted in car_info 'Specs' column.
#
# In addition to 'Access' and 'OTS', any mention of 'Stage' indicates a COBB Tuning powertrain modification that generally requires an AccessPORT/OTS to adjust the engine control computer to perform best with the new parts.
#
# We will create a feature for these words indicating that the engine control computer has been modified.

# %%
# create feature
tuned_cpu_keywords = ['Access','OTS','Stage','stage','Map','map','ProTune','Protune', 
                      'Pro-tune', 'ProTUNE', 'COBB AP', 'Cobb AP']
info['tuned_cpu'] = info.Specs.str.contains('|'.join(tuned_cpu_keywords))
# check work
info.sample(7, random_state=2)
# Out:
#        Run             Name  \
# 3623  2952  Mohamed Alsabah
# 2079  1017       Kyle White
# 4110  4842         Joseph R
# 1966   757    Daniel Fisher
# 2198  2232  Aaron Singleton
# 1364   384     Kyle Schmidt
# 313   4858         Jeremy G
#
#                                                                                                                                                                                             Specs  \
# 3623                                                                                                                                                                        Alpha 9 95 octane map
# 2079                                                                            COBB Tuning AccessPORT, GTSpec Exhaust Manifold/Up Pipe, Cobb Downpipe, Cobb SF Intake, Catback- 17psi- 92 Octane
# 4110                                                                                                                                                                             Invidia Downpipe
# 1966                     COBB Tuning AccessPORT, SPT Catback, COBB Tuning Downpipe, Deatschwerks 1000cc Injectors, Walbro Fuel Pump, K&N Typhoon Intake, Perrin TMIC, Tial 44mm EWG- 18.5psi- E85
# 2198  COBB Tuning AccessPORT, TurboXS FMIC, Catless Turboback, DOM 3 w/3" Inlet, 38mm EWG, KS 73mm Intake, TGV Deletes, Deatschwerks 1300cc Injectors, Manual Boost Controller - 23psi- 92 Octane
# 1364                                          Blouch TD06-20G, DW850cc Injectors, Walbro Fuel Pump, GrimmSpeed Manifold/Up Pipe/44mm Wastegate Kit, Perrin FMIC, Perrin Big MAF- 19psi- 92 Octane
# 313                                                                                                                                        VF22, TMIC, Sti Pinks, Perring TIH, Perrin Intake, TBE
#
#      car_year car_make             car_model  has_keyword   psi  octane  \
# 3623     2012   Nissan             2012 GT-R        False  21.0      95
# 2079     2006   Subaru     2006 Legacy 2.5GT        False    17      92
# 4110     2013   Subaru      2013 Impreza WRX        False  17.5      92
# 1966     2009   Subaru      2009 Impreza WRX        False  18.5     105
# 2198     2007   Subaru  2007 Impreza WRX STI        False    23      92
# 1364     2005   Subaru  2005 Impreza WRX STI        False    19      92
# 313      2002   Subaru      2002 Impreza WRX        False  17.0      92
#
#       stock_hp  tuned_cpu
# 3623       530       True
# 2079       250       True
# 4110       265      False
# 1966       265       True
# 2198       300       True
# 1364       300      False
# 313        227      False

# %% [markdown]
# ## Final Thoughts on Feature Engineering the 'Specs' Column
# ### Stopping with above features due to lack of information
# So I've created a few features indicating boost PSI, fuel octane, stock horsepower, and whether the engine control computer has been modified or not. Because of the nature of the *hand-entered* 'Specs' values, additional feature engineering would not be reliable.
# 1. We can't say for sure that one car has something, and another car does not.
# 2. Specific modifications are likely to have low overall counts, making the feature less useful for prediction.
#
# ### Potential for owner-by-owner analysis
# Now, what may be valuable in a second post-MVP iteration is to look at cars that have been run multiple times with different setups. We know that certain cars are run multiple times with different setups thanks to the 'Name' column.
# 1. Comparing one person's car across multiple different runs may indicate that certain parts improve performance.
# 2. This analysis may prove valuable as an insight, but would not be valuable for prediction.

# %%
# check prep_explore function
info_train, runs_train = wrangle.prep_explore()

# %%
info.head()
# Out:
#    Run            Name  \
# 0    4     GOTO:Racing
# 1   33  Dave Pickering
# 2   54      Tim Bailey
# 3   55      Tim Bailey
# 4   66  Samuel Frankel
#
#                                                                                                                                                                                          Specs  \
# 0  Stock engine internals, AMS turbo upgrade, Deatschwerks 800cc injectors, full catless 3" open exhaust, Harman Motive custom 3.1" ID intake with stock MAF sensors, 100 octane unleaded fuel
# 1                                                                                                  2009 GTR - stage 2 with full exhaust and stock downpipes - cobb v110 stage 2 92 octane beta
# 2                                                                                                                                                                   2009 GTR stage 2 91 octane
# 3                                                                                                                                                                   2009 GTR stage 2 93 octane
# 4                                                                                                                                                                 Cat Back Ext. Stage 2 19 psi
#
#   car_year car_make  car_model  has_keyword   psi  octane  stock_hp  tuned_cpu
# 0     2009   Nissan  2009 GT-R        False  22.0     100       480      False
# 1     2009   Nissan  2009 GT-R        False  17.5      92       480       True
# 2     2009   Nissan  2009 GT-R        False  17.0      91       480       True
# 3     2009   Nissan  2009 GT-R        False  17.0      93       480       True
# 4     2009   Nissan  2009 GT-R        False    19      92       480       True

# %%
runs.head()
# Out:
#    Run     RPM     HP  Torque  Boost
# 0    4  2200.0  106.1   252.5   4.12
# 1    4  2300.0  145.8   333.1   5.43
# 2    4  2400.0  177.9   389.5   6.78
# 3    4  2500.0  202.3   424.9   8.15
# 4    4  2600.0  221.8   447.9   9.55
